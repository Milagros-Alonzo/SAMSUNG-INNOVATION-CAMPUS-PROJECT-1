# %%
import pandas as pd
import os

# --- Configuración para mostrar todas las columnas ---
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50) # Solo para las primeras 50 filas
pd.set_option('display.width', 1000) 

# --- Carga del Dataset ---
# Define la ruta relativa al archivo original
RUTA_DATA_BRUTA = '../Data/dataset_estudiantes_modifcado.xlsx'

try:
    df = pd.read_excel(RUTA_DATA_BRUTA) 
    
    print("--- Carga de datos EXCEL exitosa ---")
    
    # Inspección inicial
    print(f"Dimensiones del DataFrame: {df.shape[0]} filas, {df.shape[1]} columnas")
    print("\nPrimeras 5 filas (cabecera):")
    print(df.head())
    
    print("\nTipos de datos y valores no nulos:")
    df.info()
    
except FileNotFoundError:
    print(f"ERROR: Archivo no encontrado en la ruta: {RUTA_DATA_BRUTA}. Asegúrate de que el archivo esté en data/01_raw/")
except Exception as e:
    print(f"ERROR al cargar el archivo. Verifica el separador (sep='\t'): {e}")
# Out:
# --- Carga de datos EXCEL exitosa ---
# Dimensiones del DataFrame: 1549 filas, 1 columnas
#
# Primeras 5 filas (cabecera):
# ...
